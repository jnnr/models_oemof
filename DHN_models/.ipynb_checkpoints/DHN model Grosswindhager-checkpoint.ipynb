# %% [markdown]
# # DHN model

# %% [markdown]
# [1] S. Grosswindhager, A. Voigt, and M. Kozek, “Efficient Physical Modelling of District Heating Networks,” Model. Simul., no. 2, 2011.
#
# ![Screenshot_2018-06-12_16-42-53.png](attachment:Screenshot_2018-06-12_16-42-53.png)
